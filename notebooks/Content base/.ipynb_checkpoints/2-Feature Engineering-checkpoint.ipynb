# %% [markdown]
# Feature Engineering

# %%
CLEAND_BOOKS = r'..\..\data\processed\cleaned_books.csv'
CLEAND_Rating = r'..\..\data\processed\cleaned_Rating.csv'
CLEAND_Users = r'..\..\data\processed\cleaned_users.csv'

FINAL_DF = r'..\..\data\processed\For content base\Final_content_base.csv'

# %% [markdown]
# ### Importing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books_df = pd.read_csv(CLEAND_BOOKS)
rating_df = pd.read_csv(CLEAND_Rating)
users_df = pd.read_csv(CLEAND_Users)

# %%
books_df
# Out:
#               ISBN                                              Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 237426  0449906736      Flashpoints: Promise and Peril in a New World
# 237427  0525447644                            From One to One Hundred
# 237428  006008667X  Lily Dale : The True Story of the Town that Ta...
# 237429  0192126040                        Republic (World's Classics)
# 237430  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       Author  Publication_year  \
# 0         Mark P. O. Morford              2002
# 1       Richard Bruce Wright              2001
# 2               Carlo D'Este              1991
# 3           Gina Bari Kolata              1999
# 4            E. J. W. Barber              1999
# ...                      ...               ...
# 237426          Robin Wright              1993
# 237427            Teri Sloat              1991
# 237428      Christine Wicker              2004
# 237429                 Plato              1996
# 237430   Christopher  Biffle              2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 237426                                  Ballantine Books
# 237427                                      Dutton Books
# 237428                                HarperSanFrancisco
# 237429                           Oxford University Press
# 237430  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                                Book_image
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 237426  http://images.amazon.com/images/P/0449906736.0...
# 237427  http://images.amazon.com/images/P/0525447644.0...
# 237428  http://images.amazon.com/images/P/006008667X.0...
# 237429  http://images.amazon.com/images/P/0192126040.0...
# 237430  http://images.amazon.com/images/P/0767409752.0...
#
# [237431 rows x 6 columns]

# %%
rating_df
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %% [markdown]
# get average and number of rating for each book , so we can measure the book popularity in our rank based recommendation system

# %%
avg_books_rating = rating_df.groupby(
    'ISBN')['Book-Rating'].mean().reset_index()

# %%
avg_books_rating
# Out:
#                ISBN  Book-Rating
# 0        0330299891          3.0
# 1        0375404120          1.5
# 2        0586045007          0.0
# 3        9022906116          3.5
# 4        9032803328          0.0
# ...             ...          ...
# 340551     cn113107          0.0
# 340552   ooo7156103          7.0
# 340553   §423350229          0.0
# 340554  ´3499128624          8.0
# 340555    Ô½crosoft          7.0
#
# [340556 rows x 2 columns]

# %%
avg_books_rating['Rating_count'] = rating_df.groupby(
    'ISBN')['Book-Rating'].count().reset_index()['Book-Rating']

# %%
avg_books_rating = avg_books_rating.rename(columns={
    'Book-Rating': 'Avg_rating'
})

# %% [markdown]
# Now we will merge that with books df

# %%
books_df = books_df.merge(avg_books_rating, on='ISBN')

# %%
books_df.sort_values(by='Rating_count', ascending=False)
# Out:
#               ISBN                                              Title  \
# 26      0971880107                                        Wild Animus
# 399     0316666343                          The Lovely Bones: A Novel
# 724     0385504209                                  The Da Vinci Code
# 1065    0060928336    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 511     0312195516                The Red Tent (Bestselling Backlist)
# ...            ...                                                ...
# 128455  0761913130  Communication Planning : An Integrated Approac...
# 128454  1869584287                                         Revolution
# 128453  0971498814  Corporate Storytelling: Planning and Creating ...
# 128452  020716374X  Don't you worry about that!: The Joh Bjelke-Pe...
# 236372  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                            Author  Publication_year  \
# 26                   Rich Shapero              2004
# 399                  Alice Sebold              2002
# 724                     Dan Brown              2003
# 1065                Rebecca Wells              1997
# 511                 Anita Diamant              1998
# ...                           ...               ...
# 128455  Sherry Devereaux Ferguson              1999
# 128454             Marcia Russell              1996
# 128453           Lecia Vonne Wood              2002
# 128452   Johannes Bjelke-Petersen              1990
# 236372        Christopher  Biffle              2000
#
#                                                Publisher  \
# 26                                               Too Far
# 399                                        Little, Brown
# 724                                            Doubleday
# 1065                                           Perennial
# 511                                          Picador USA
# ...                                                  ...
# 128455                                 Sage Publications
# 128454                                Hodder Moa Beckett
# 128453                                     Grendel Press
# 128452                             Angus &amp; Robertson
# 236372  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                                Book_image  Avg_rating  \
# 26      http://images.amazon.com/images/P/0971880107.0...    1.019584
# 399     http://images.amazon.com/images/P/0316666343.0...    4.468726
# 724     http://images.amazon.com/images/P/0385504209.0...    4.652322
# 1065    http://images.amazon.com/images/P/0060928336.0...    3.448087
# 511     http://images.amazon.com/images/P/0312195516.0...    4.334716
# ...                                                   ...         ...
# 128455  http://images.amazon.com/images/P/0761913130.0...    8.000000
# 128454  http://images.amazon.com/images/P/1869584287.0...    0.000000
# 128453  http://images.amazon.com/images/P/0971498814.0...    8.000000
# 128452  http://images.amazon.com/images/P/020716374X.0...    0.000000
# 236372  http://images.amazon.com/images/P/0767409752.0...    0.000000
#
#         Rating_count
# 26              2502
# 399             1295
# 724              883
# 1065             732
# 511              723
# ...              ...
# 128455             1
# 128454             1
# 128453             1
# 128452             1
# 236372             1
#
# [236373 rows x 8 columns]

# %%
books_df.columns
# Out:
# Index(['ISBN', 'Title', 'Author', 'Publication_year', 'Publisher',
#        'Book_image', 'Avg_rating', 'Rating_count'],
#       dtype='object')

# %%
books_df.to_csv(FINAL_DF, index=False)
